# %%
import numpy as np
from scipy.optimize import approx_fprime
from scipy.misc import derivative
from sympy import *
from sympy import symbols, diff
from scipy.optimize import minimize, approx_fprime, fmin, brute

# %% [markdown]
# ### Задание 1:
# Посчитайте частные производные функций
# (как обычно, необходимо решение на бумажке или в LaTeX и на scipy):

# %% [markdown]
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$, а для этой функции также градиент в точке $(1,2)$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %% [markdown]
# $ 1) $
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$
# $f'_x=4xy^3-1/x^2 + y^2      $
# $f'_y= 6x^2y^2 + 1/x+ 2yx     $
#
# $f′𝑥(1,2)=32-1+4=35 $
#
# $𝑓′𝑦(1,2)=24+4=28 $
#
# $ 𝑔𝑟𝑎𝑑𝑓(1,2)=(35,28) $

# %% [markdown]
# $ 2) $
# $ f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y $
# $ f'x = 2xy - y*sin(xy) - 2*x * cos(x^2) + 6*y $
# $ f'y = x^2 - x*sin(xy) - cos(x^2) $

# %% [markdown]
# ### Задание 2:
#
# Градиентный спуск своими руками

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
lr = 0.1

# %%
gradient_dict = {}

for i in range(100):
    eps = np.sqrt(np.finfo(float).eps)
    gradient = approx_fprime(x, f, eps)
    gradient_dict[f(x)] = gradient
    print(f"Значении функции {f(x)} в точках  {gradient}")
    x = x - x * lr
# Out:
# Значении функции 50000 в точках  [200. 400.]
# Значении функции 40500.0 в точках  [180. 360.]
# Значении функции 32805.0 в точках  [162. 324.]
# Значении функции 26572.050000000003 в точках  [145.80004883 291.60009766]
# Значении функции 21523.3605 в точках  [131.2199707  262.43994141]
# Значении функции 17433.922005 в точках  [118.09790039 236.19604492]
# Значении функции 14121.476824050002 в точках  [106.28808594 212.57641602]
# Значении функции 11438.3962274805 в точках  [ 95.65942383 191.31872559]
# Значении функции 9265.100944259204 в точках  [ 86.09350586 172.18688965]
# Значении функции 7504.731764849957 в точках  [ 77.48406982 154.96820068]
# Значении функции 6078.8327295284635 в точках  [ 69.73571777 139.47137451]
# Значении функции 4923.854510918055 в точках  [ 62.762146   125.52429199]
# Значении функции 3988.3221538436246 в точках  [ 56.4859314  112.97186279]
# Значении функции 3230.5409446133363 в точках  [ 50.83734131 101.67468262]
# ...

# %%
fmin = min(list(gradient_dict.keys()))
xmin = gradient_dict[min(list(gradient_dict.keys()))]

# %%
print("Минимум достигается в: ", xmin)
print("Значение функции в минимуме: ", fmin)
# Out:
# Минимум достигается в:  [0.00590255 0.01180508]
# Значение функции в минимуме:  4.354987104108225e-05

# %% [markdown]
# Проверка с помощью встроенной функции numpy:

# %%
minimize(f, x, method='nelder-mead', options={'xtol': 1e-8, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 103
#  final_simplex: (array([[ 2.24361697e-09, -1.81656623e-09],
#        [ 6.94706168e-09,  2.73301746e-09],
#        [-2.65586682e-09,  7.41388838e-09]]), array([8.33372998e-18, 5.57310504e-17, 6.20193695e-17]))
#            fun: 8.333729977023065e-18
#        message: 'Optimization terminated successfully.'
#           nfev: 103
#            nit: 54
#         status: 0
#        success: True
#              x: array([ 2.24361697e-09, -1.81656623e-09])
