# %% [markdown]
# ### Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
rating = pd.read_csv('/home/denis/MyProjects/Netology/HomeWork/12_pandas/ml-latest-small/ratings.csv')
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
film = pd.read_csv('/home/denis/MyProjects/Netology/HomeWork/12_pandas/ml-latest-small/movies.csv')

# %%
film.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
films_rating = pd.merge(film, rating, on=('movieId'))

# %%
films_rating.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
filter_5_star = films_rating[ films_rating.rating == 5 ]
filter_5_star['title'].value_counts().head()
# Out:
# Shawshank Redemption, The (1994)             153
# Pulp Fiction (1994)                          123
# Forrest Gump (1994)                          116
# Matrix, The (1999)                           109
# Star Wars: Episode IV - A New Hope (1977)    104
# Name: title, dtype: int64

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('/home/denis/MyProjects/Netology/LECTURE/11/power.csv')

# %%
filter_power = power[(power.country.isin(['Latvia', 'Lithuania', 'Estonia']))&(power.category.isin([4, 12, 21]))&(power.year>= 2005)&(power.year<= 2010)&(power.quantity>=0)]

# %%
filter_power.quantity.sum()
# Out:
# 240580.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'

# %%
df = pd.read_html(page_url, attrs = {'class': 'quote_list'}, encoding='utf-8')

# %%
df[0].iloc[:, 1:]
# Out:
#                 Рубль  Предложение  Спрос  Предыдущее закрытие        %  \
# 0             GBP/RUB       892583      -               894699  -0,24 %
# 1             EUR/RUB       803235      -               805130  -0,24 %
# 2             USD/RUB       711771      -               714700  -0,41 %
# 3             JPY/RUB        06619      -                06630  -0,17 %
# 4             CNY/RUB       101407      -               101657  -0,25 %
# 5             CHF/RUB       755970      -               756441  -0,06 %
# 6                Евро  Предложение  Спрос  Предыдущее закрытие        %
# 7             EUR/USD        11286      -                11275   0,10 %
# 8             EUR/GBP        08997      -                08985   0,13 %
# 9             EUR/JPY      1213350      -              1212500   0,07 %
# 10            EUR/CHF        10625      -                10631  -0,06 %
# 11         Доллар США  Предложение  Спрос  Предыдущее закрытие        %
# ...
